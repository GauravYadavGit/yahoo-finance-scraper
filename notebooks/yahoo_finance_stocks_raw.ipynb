# %%
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains

chrome_version = "142.0.7444.176"

service = Service(
    ChromeDriverManager(driver_version=chrome_version).install()
)
driver = webdriver.Chrome(service=service)


driver.maximize_window()

wait = WebDriverWait(driver, 5)

def wait_for_page_to_load(driver, wait):

    page_title = driver.title
    
    try:
        
        wait.until(
            lambda driver : driver.execute_script("return document.readyState") == 'complete'
        )
    
    except Exception as e:
        print(f"page {page_title} was not loaded within time with error msg : {e}")
    
    else:
        print(f"page {page_title} was loaded within time")


url = "https://finance.yahoo.com/"
driver.get(url)

wait_for_page_to_load(driver, wait)

actions = ActionChains(driver)

market_menu = wait.until(
    EC.presence_of_element_located((By.XPATH, '//*[@id="navigation-container"]/ol/li[3]/a/div'))
)

actions.move_to_element(market_menu).perform()


stocks_menu = wait.until(
    EC.presence_of_element_located((By.XPATH, '//*[@id="navigation-container"]/ol/li[3]/ol/li[1]/a/span'))
)

actions.move_to_element(stocks_menu).perform()

trending_menu = wait.until(
    EC.element_to_be_clickable((By.XPATH, '//*[@id="navigation-container"]/ol/li[3]/ol/li[1]/ol/li[4]/a/span'))
)

trending_menu.click()

wait_for_page_to_load(driver, wait)

most_active = wait.until(
    EC.element_to_be_clickable((By.XPATH, '//*[@id="tab-most-active"]'))
)

most_active.click()

wait_for_page_to_load(driver, wait)

data = []


while True:

    wait.until(
        EC.presence_of_element_located((By.TAG_NAME, 'table'))
    )

    rows = driver.find_elements(By.CSS_SELECTOR, 'table tbody tr')
    for row in rows:
        values = row.find_elements(By.TAG_NAME, 'td')
        print([val.text for val in values])
        stock = {
            "name": values[1].text,
            "symbol": values[0].text,
            "price": values[3].text,
            "change": values[4].text,
            "volumn": values[6].text,
            "market_cap": values[8].text,
            "pe_ratio": values[9].text
        }
        data.append(stock)
    
    try:
        
        next_button = wait.until(
            EC.element_to_be_clickable((By.XPATH, '//*[@id="main-content-wrapper"]/section[1]/div/div[4]/div[3]/button[3]'))
        )

    except:
        print("the \"next\" button is not clickable as we have gone through all pages.")
        break
    else:
        next_button.click()
        
        time.sleep(1)
    



driver.quit()
# Out:
# page Yahoo Finance - Stock Market Live, Quotes, Business & Finance News was loaded within time
# page Yahoo Finance - Stock Market Live, Quotes, Business & Finance News was loaded within time
# page Top Trending Stocks: US stocks with the highest interest today - Yahoo Finance was loaded within time
# ['OLMA', 'Olema Pharmaceuticals, Inc.', '', '20.14', '+11.62', '+136.38%', '85.927M', '1.194M', '1.383B', '--', '-2.29%', '2.86\n27.17']
# ['HD', 'The Home Depot, Inc.', '', '336.48', '-21.55', '-6.02%', '9.079M', '3.458M', '334.928B', '22.86', '-11.99%', '326.31\n439.37']
# ['WBD', 'Warner Bros. Discovery, Inc.', '', '23.69', '+0.95', '+4.18%', '58.421M', '51.304M', '58.703B', '124.68', '+139.37%', '7.52\n24.19']
# ['MSFT', 'Microsoft Corporation', '', '493.79', '-13.70', '-2.70%', '32.649M', '21.163M', '3.67T', '35.12', '+21.47%', '344.79\n555.45']
# ['NET', 'Cloudflare, Inc.', '', '196.53', '-5.72', '-2.83%', '8.033M', '2.505M', '68.841B', '--', '+109.87%', '89.42\n260.00']
# ['TMC', 'TMC the metals company Inc.', '', '5.42', '+0.53', '+10.95%', '10.324M', '9.304M', '2.899B', '--', '+18.18%', '214.25\n488.54']
# ['F', 'Ford Motor Company', '', '13.02', '+0.14', '+1.09%', '65.744M', '90.177M', '51.878B', '11.28', '+16.56%', '8.44\n13.97']
# ['SOFI', 'SoFi Technologies, Inc.', '', '26.23', '-0.81', '-3.00%', '64.447M', '74.466M', '31.631B', '51.32', '+87.52%', '8.60\n32.73']
# ['QUBT', 'Quantum Computing Inc.', '', '12.34', '+0.84', '+7.30%', '64.003M', '36.657M', '2.763B', '--', '+352.76%', '2.44\n27.15']
# ['PFE', 'Pfizer Inc.', '', '25.45', '+0.37', '+1.48%', '58.147M', '65.441M', '144.701B', '14.56', '-0.08%', '20.92\n27.69']
# ['DNN', 'Denison Mines Corp.', '', '2.38', '-0.01', '-0.42%', '56.968M', '85.042M', '2.136B', '--', '+0.84%', '1.08\n3.42']
# ['WBD', 'Warner Bros. Discovery, Inc.', '', '23.70', '+0.97', '+4.24%', '55.466M', '51.304M', '58.74B', '118.64', '+139.37%', '7.52\n23.19']
# ['ACHR', 'Archer Aviation Inc.', '', '7.59', '+0.17', '+2.29%', '54.705M', '54.185M', '4.943B', '--', '+44.64%', '4.33\n14.62']
# ['AMZN', 'Amazon.com, Inc.', '', '222.68', '-10.19', '-4.38%', '52.965M', '45.934M', '2.38T', '33.16', '+13.81%', '161.38\n258.60']
# ['SNAP', 'Snap Inc.', '', '8.25', '+0.07', '+0.86%', '52.813M', '93.21M', '14.185B', '--', '-22.17%', '6.90\n13.28']
# ['WULF', 'TeraWulf Inc.', '', '12.00', '+0.95', '+8.60%', '52.59M', '43.926M', '5.024B', '--', '+49.73%', '2.06\n17.05']
# ['NIO', 'NIO Inc.', '', '5.98', '-0.10', '-1.64%', '52.536M', '78.839M', '14.736B', '--', '+31.32%', '3.02\n8.02']
# ['INTC', 'Intel Corporation', '', '34.37', '-0.34', '-0.99%', '52.025M', '117.651M', '163.921B', '788.93', '+43.43%', '17.67\n42.48']
# ['BMNR', 'Bitmine Immersion Technologies, Inc.', '', '32.28', '+1.33', '+4.30%', '50.583M', '44.681M', '9.191B', '--', '+299.35%', '3.92\n161.00']
# ['PLTR', 'Palantir Technologies Inc.', '', '167.43', '-3.82', '-2.23%', '49.063M', '62.683M', '399.059B', '1,612.20', '+171.91%', '59.27\n207.52']
# ['MARA', 'MARA Holdings, Inc.', '', '11.86', '+0.35', '+3.04%', '46.565M', '56.777M', '4.485B', '5.64', '-42.04%', '9.81\n30.28']
# ['NOK', 'Nokia Oyj', '', '6.64', '-0.02', '-0.30%', '46.056M', '46.02M', '36.822B', '37.02', '+60.48%', '3.91\n8.19']
# ['AAL', 'American Airlines Group Inc.', '', '12.36', '+0.02', '+0.16%', '45.301M', '70.42M', '8.159B', '15.53', '-13.89%', '8.50\n19.10']
# ['GOOGL', 'Alphabet Inc.', '', '284.27', '-0.75', '-0.26%', '43.511M', '34.044M', '3.443T', '27.27', '+60.02%', '140.53\n293.95']
# ['CIFR', 'Cipher Mining Inc.', '', '14.58', '+0.23', '+1.60%', '42.306M', '49.247M', '5.76B', '--', '+114.82%', '1.86\n25.52']
# ['NFLX', 'Netflix, Inc.', '', '114.09', '+3.80', '+3.45%', '41.898M', '35.966M', '483.436B', '46.48', '+26.58%', '82.11\n134.12']
# ['AMD', 'Advanced Micro Devices, Inc.', '', '230.36', '-10.16', '-4.22%', '40.994M', '58.151M', '375.036B', '129.23', '+72.55%', '76.48\n267.08']
# ['ABEV', 'Ambev S.A.', '', '2.53', '-0.01', '-0.39%', '40.078M', '40.443M', '40.307B', '13.42', '+16.51%', '1.76\n2.64']
# ['RIG', 'Transocean Ltd.', '', '4.13', '+0.05', '+1.23%', '39.673M', '45.906M', '4.549B', '--', '-2.86%', '1.97\n4.51']
# ['RGTI', 'Rigetti Computing, Inc.', '', '25.71', '+1.02', '+4.13%', '39.623M', '81.403M', '8.485B', '--', '+1,784.73%', '1.29\n58.15']
# ['LNW', 'Light & Wonder, Inc.', '', '86.22', '0.00', '0.00%', '38.855M', '1.956M', '7.029B', '19.16', '-4.78%', '69.56\n113.95']
# ['RIVN', 'Rivian Automotive, Inc.', '', '14.99', '+0.12', '+0.84%', '38.721M', '50.842M', '18.383B', '--', '+46.21%', '9.90\n18.13']
# ['HPE', 'Hewlett Packard Enterprise Company', '', '20.90', '-0.33', '-1.55%', '37.811M', '30.455M', '27.583B', '26.51', '-1.39%', '11.97\n26.44']
# ['IREN', 'IREN Limited', '', '48.85', '+1.44', '+3.04%', '35.705M', '40.099M', '13.844B', '23.32', '+355.43%', '5.13\n76.87']
# ['BAC', 'Bank of America Corporation', '', '51.64', '+0.16', '+0.31%', '35.114M', '35.343M', '515.793B', '14.37', '+10.92%', '33.07\n54.69']
# ['T', 'AT&T Inc.', '', '25.60', '+0.13', '+0.51%', '35.082M', '46.384M', '181.561B', '8.31', '+12.05%', '21.38\n29.79']
# ['KVUE', 'Kenvue Inc.', '', '16.23', '-0.01', '-0.06%', '34.722M', '37.839M', '31.147B', '22.28', '-31.45%', '14.02\n25.17']
# ['GRAB', 'Grab Holdings Limited', '', '5.32', '-0.01', '-0.19%', '33.827M', '51.287M', '21.743B', '269.29', '-2.38%', '3.36\n6.62']
# ['MU', 'Micron Technology, Inc.', '', '228.50', '-13.45', '-5.56%', '33.132M', '24.502M', '256.483B', '32.52', '+147.57%', '61.54\n260.58']
# ['CLF', 'Cleveland-Cliffs Inc.', '', '11.19', '+0.22', '+2.01%', '33.087M', '27.17M', '6.375B', '--', '-4.11%', '5.63\n16.70']
# ['NU', 'Nu Holdings Ltd.', '', '15.32', '-0.28', '-1.79%', '32.342M', '43.18M', '74.032B', '30.67', '+15.90%', '9.01\n16.55']
# ['AAPL', 'Apple Inc.', '', '267.44', '-0.02', '-0.01%', '32.293M', '50.504M', '3.969T', '36.52', '+17.16%', '169.21\n277.32']
# ['MSFT', 'Microsoft Corporation', '', '493.79', '-13.70', '-2.70%', '31.801M', '21.163M', '3.67T', '36.29', '+21.47%', '344.79\n555.45']
# ['CRWV', 'CoreWeave, Inc.', '', '74.90', '-0.43', '-0.57%', '31.755M', '30.011M', '37.339B', '--', '+88.32%', '33.52\n187.00']
# ['SOUN', 'SoundHound AI, Inc.', '', '11.53', '+0.10', '+0.87%', '31.73M', '56.456M', '4.844B', '--', '+75.58%', '6.04\n24.98']
# ['BBD', 'Banco Bradesco S.A.', '', '3.60', '-0.02', '-0.55%', '28.739M', '47.44M', '38.253B', '9.67', '+50.21%', '1.84\n3.77']
# ['RKT', 'Rocket Companies, Inc.', '', '16.97', '+0.55', '+3.35%', '28.635M', '38.202M', '47.776B', '--', '+19.77%', '10.06\n22.56']
# ['QS', 'QuantumScape Corporation', '', '12.97', '+0.02', '+0.15%', '28.394M', '41.315M', '7.823B', '--', '+161.62%', '3.40\n19.07']
# ['B', 'Barrick Mining Corporation', '', '37.74', '+0.78', '+2.11%', '28.371M', '21.595M', '64.529B', '17.82', '+108.58%', '15.11\n38.16']
# ['BTG', 'B2Gold Corp.', '', '3.9900', '0.00', '0.00%', '27.556M', '49.145M', '5.304B', '26.63', '+42.50%', '2.20\n5.94']
# ['BTE', 'Baytex Energy Corp.', '', '3.14', '+0.12', '+3.97%', '27.399M', '23.543M', '2.416B', '16.19', '+2.37%', '1.36\n3.25']
# ['HOOD', 'Robinhood Markets, Inc.', '', '114.29', '-1.68', '-1.45%', '26.966M', '36.284M', '102.768B', '51.24', '+229.09%', '29.66\n153.86']
# ['APLD', 'Applied Digital Corporation', '', '22.84', '-0.09', '-0.41%', '26.628M', '30.559M', '6.388B', '--', '+150.38%', '3.31\n40.20']
# ['VALE', 'Vale S.A.', '', '12.17', '0.00', '0.00%', '26.435M', '30.329M', '52.075B', '9.25', '+21.46%', '8.06\n12.60']
# ['QBTS', 'D-Wave Quantum Inc.', '', '22.93', '+0.10', '+0.44%', '26.306M', '52.732M', '8.028B', '--', '+1,432.21%', '1.44\n46.75']
# ['NBIS', 'Nebius Group N.V.', '', '90.54', '+4.56', '+5.30%', '25.98M', '19.322M', '22.799B', '169.64', '+316.37%', '18.31\n141.10']
# ['SMCI', 'Super Micro Computer, Inc.', '', '34.90', '+0.80', '+2.35%', '25.598M', '29.409M', '20.834B', '28.97', '+20.62%', '24.82\n66.44']
# ['HIMS', 'Hims & Hers Health, Inc.', '', '36.26', '+0.68', '+1.91%', '25.193M', '28.69M', '8.255B', '68.88', '+51.21%', '20.02\n72.98']
# ['GOOG', 'Alphabet Inc.', '', '284.96', '-0.64', '-0.22%', '24.903M', '21.958M', '3.441T', '27.27', '+59.04%', '142.66\n294.52']
# ['RXRX', 'Recursion Pharmaceuticals, Inc.', '', '4.16', '+0.04', '+0.97%', '24.857M', '41.632M', '2.168B', '--', '-34.29%', '3.79\n12.36']
# ['PCG', 'PG&E Corporation', '', '16.15', '-0.18', '-1.10%', '24.804M', '23.532M', '35.496B', '13.88', '-22.24%', '12.97\n21.72']
# ['MRK', 'Merck & Co., Inc.', '', '96.43', '+3.57', '+3.84%', '24.541M', '12.298M', '240.861B', '12.30', '-3.81%', '73.31\n105.07']
# ['MTSR', 'Metsera, Inc.', '', '70.50', '-0.25', '-0.35%', '24.518M', '3.198M', '7.429B', '--', '+166.04%', '12.30\n83.86']
# ['CLSK', 'CleanSpark, Inc.', '', '10.81', '+0.20', '+1.89%', '23.924M', '30.99M', '2.89B', '11.17', '-24.86%', '6.45\n23.61']
# ['HBAN', 'Huntington Bancshares Incorporated', '', '15.35', '+0.05', '+0.33%', '23.798M', '30.755M', '24.059B', '11.00', '-12.77%', '11.92\n18.45']
# ['EOSE', 'Eos Energy Enterprises, Inc.', '', '13.48', '+0.48', '+3.69%', '23.749M', '21.193M', '3.886B', '--', '+462.77%', '2.07\n19.86']
# ['CMCSA', 'Comcast Corporation', '', '27.36', '+0.14', '+0.51%', '23.72M', '27.579M', '101.019B', '4.57', '-35.68%', '25.75\n44.03']
# ['FCX', 'Freeport-McMoRan Inc.', '', '40.00', '+1.00', '+2.56%', '23.453M', '18.062M', '57.437B', '28.09', '-11.60%', '27.66\n49.12']
# ['AMCR', 'Amcor plc', '', '8.46', '+0.01', '+0.12%', '23.29M', '23.518M', '19.529B', '26.44', '-14.56%', '7.67\n10.71']
# ['OWL', 'Blue Owl Capital Inc.', '', '13.91', '+0.14', '+1.02%', '22.874M', '11.683M', '21.744B', '188.56', '-41.15%', '13.36\n26.73']
# ['META', 'Meta Platforms, Inc.', '', '597.69', '-4.32', '-0.72%', '22.683M', '15.29M', '1.506T', '26.93', '+7.29%', '479.80\n796.25']
# ['RF', 'Regions Financial Corporation', '', '24.18', '-0.12', '-0.49%', '22.255M', '25.726M', '21.576B', '11.00', '-7.46%', '17.74\n27.96']
# ['SMR', 'NuScale Power Corporation', '', '21.54', '+0.48', '+2.28%', '21.252M', '21.108M', '3.616B', '--', '-22.06%', '11.08\n57.42']
# ['JOBY', 'Joby Aviation, Inc.', '', '13.93', '+0.04', '+0.29%', '20.647M', '42.26M', '12.701B', '--', '+119.43%', '4.96\n20.95']
# ['LUMN', 'Lumen Technologies, Inc.', '', '7.62', '-0.44', '-5.46%', '20.565M', '19.793M', '7.819B', '--', '+4.13%', '3.01\n11.95']
# ['MRVL', 'Marvell Technology, Inc.', '', '78.68', '-4.80', '-5.75%', '20.29M', '21.019M', '67.838B', '--', '-6.59%', '47.09\n127.48']
# ['AGNC', 'AGNC Investment Corp.', '', '10.11', '+0.01', '+0.10%', '20.244M', '20.912M', '10.845B', '14.42', '+4.45%', '7.85\n10.63']
# ['CSCO', 'Cisco Systems, Inc.', '', '77.37', '-0.41', '-0.53%', '20.095M', '19.772M', '305.859B', '30.12', '+36.43%', '52.11\n79.50']
# ['VZ', 'Verizon Communications Inc.', '', '41.48', '+0.47', '+1.15%', '20.073M', '24.874M', '174.897B', '8.76', '-2.19%', '37.59\n47.36']
# ['MDT', 'Medtronic plc', '', '100.80', '+4.52', '+4.69%', '19.606M', '6.931M', '129.288B', '26.48', '+13.27%', '79.29\n99.37']
# ['MSTR', 'Strategy Inc', '', '206.80', '+11.38', '+5.82%', '19.1M', '12.047M', '59.445B', '7.31', '-54.61%', '189.53\n543.00']
# ['IONQ', 'IonQ, Inc.', '', '49.12', '+1.33', '+2.78%', '18.996M', '28.871M', '17.432B', '--', '+71.35%', '17.88\n84.64']
# ['ORCL', 'Oracle Corporation', '', '220.49', '+0.63', '+0.29%', '18.501M', '24.686M', '629.455B', '51.60', '+16.39%', '118.86\n345.72']
# ['PDD', 'PDD Holdings Inc.', '', '119.58', '-9.46', '-7.33%', '18.47M', '8.769M', '169.761B', '14.06', '+9.65%', '87.11\n139.41']
# ['CMG', 'Chipotle Mexican Grill, Inc.', '', '30.76', '+0.23', '+0.75%', '18.165M', '22.129M', '41.246B', '27.96', '-48.02%', '29.75\n66.74']
# ['BULL', 'Webull Corporation', '', '8.39', '+0.24', '+2.94%', '18.026M', '21.05M', '4.151B', '24.52', '-29.16%', '7.99\n79.56']
# ['AUR', 'Aurora Innovation, Inc.', '', '3.81', '-0.02', '-0.52%', '17.872M', '18.302M', '7.374B', '--', '-38.62%', '3.77\n10.77']
# ['RIOT', 'Riot Platforms, Inc.', '', '13.94', '+0.06', '+0.43%', '17.633M', '33.598M', '5.183B', '34.68', '+13.12%', '6.19\n23.94']
# ['AXTA', 'Axalta Coating Systems Ltd.', '', '28.00', '-0.18', '-0.64%', '16.973M', '3.475M', '6.064B', '13.82', '-27.41%', '26.28\n41.66']
# ['NGD', 'New Gold Inc.', '', '6.95', '-0.07', '-1.00%', '16.835M', '20.098M', '5.538B', '22.73', '+152.52%', '2.43\n7.75']
# ['GGB', 'Gerdau S.A.', '', '3.48', '-0.01', '-0.29%', '16.72M', '17.002M', '6.9B', '12.71', '+1.75%', '2.27\n3.66']
# ['AVGO', 'Broadcom Inc.', '', '340.50', '-2.15', '-0.63%', '16.555M', '23.293M', '1.608T', '87.97', '+107.23%', '138.10\n386.48']
# ['IQ', 'iQIYI, Inc.', '', '2.18', '+0.13', '+6.34%', '16.528M', '15.402M', '2.099B', '219.23', '-1.91%', '1.50\n2.84']
# ['KEY', 'KeyCorp', '', '17.19', '+0.07', '+0.41%', '16.521M', '24.533M', '18.849B', '20.37', '-9.89%', '12.73\n20.04']
# ['ITUB', 'Itaú Unibanco Holding S.A.', '', '7.52', '-0.04', '-0.53%', '16.484M', '26.154M', '80.61B', '9.93', '+39.06%', '4.42\n7.86']
# ['NVO', 'Novo Nordisk A/S', '', '47.55', '-0.91', '-1.88%', '16.163M', '15.196M', '211.376B', '13.33', '-52.78%', '45.05\n112.52']
# ['SNDK', 'Sandisk Corporation', '', '244.93', '-20.95', '-7.88%', '16.162M', '8.248M', '35.895B', '--', '+638.56%', '27.89\n284.76']
# ['RKLB', 'Rocket Lab Corporation', '', '42.78', '-0.53', '-1.22%', '15.863M', '22.901M', '22.835B', '--', '+111.27%', '14.71\n73.97']
# ['CRCL', 'Circle Internet Group', '', '76.60', '+0.01', '+0.01%', '15.752M', '12.2M', '19.509B', '--', '-7.98%', '64.00\n298.99']
# ['PYPL', 'PayPal Holdings, Inc.', '', '60.70', '-1.19', '-1.92%', '15.096M', '14.808M', '58.015B', '12.62', '-26.40%', '55.85\n93.66']
# ['CORZ', 'Core Scientific, Inc.', '', '15.43', '+0.64', '+4.33%', '15.06M', '16.288M', '4.784B', '--', '-10.20%', '6.20\n23.63']
# ['UBER', 'Uber Technologies, Inc.', '', '90.86', '-1.25', '-1.36%', '14.859M', '16.72M', '189.481B', '11.75', '+33.24%', '59.33\n101.99']
# ['JHX', 'James Hardie Industries plc', '', '17.83', '+1.14', '+6.83%', '14.778M', '8.527M', '10.328B', '21.96', '-53.57%', '16.46\n37.65']
# ['XPEV', 'XPeng Inc.', '', '22.62', '+0.19', '+0.85%', '14.69M', '11.427M', '22.119B', '--', '+79.15%', '11.14\n28.24']
# ['ET', 'Energy Transfer LP', '', '16.97', '+0.03', '+0.18%', '14.58M', '13.341M', '58.265B', '13.58', '-5.68%', '14.60\n21.45']
# ['BMY', 'Bristol-Myers Squibb Company', '', '47.06', '+0.25', '+0.53%', '14.457M', '14.992M', '95.803B', '15.70', '-19.61%', '42.52\n63.33']
# ['WMT', 'Walmart Inc.', '', '101.39', '-1.56', '-1.52%', '14.328M', '16.476M', '810.212B', '38.68', '+18.88%', '79.81\n109.58']
# ['CDE', 'Coeur Mining, Inc.', '', '14.38', '-0.08', '-0.55%', '14.116M', '16.551M', '9.235B', '20.07', '+117.12%', '4.58\n23.62']
# ['LYFT', 'Lyft, Inc.', '', '21.70', '+0.12', '+0.56%', '13.946M', '20.796M', '8.82B', '63.78', '+30.24%', '9.66\n25.54']
# ['AS', 'Amer Sports, Inc.', '', '33.36', '+2.60', '+8.45%', '13.788M', '5.231M', '18.501B', '74.31', '+48.81%', '18.56\n42.36']
# ['SLB', 'SLB N.V.', '', '36.04', '+0.24', '+0.67%', '13.613M', '16.269M', '53.841B', '14.37', '-16.94%', '31.11\n44.97']
# ['XP', 'XP Inc.', '', '18.45', '+0.35', '+1.93%', '13.577M', '7.217M', '9.722B', '10.82', '+8.51%', '10.82\n20.64']
# ['KHC', 'The Kraft Heinz Company', '', '24.97', '+0.48', '+1.96%', '13.412M', '16.291M', '29.556B', '--', '-19.91%', '23.70\n33.35']
# ['INFY', 'Infosys Limited', '', '16.95', '+0.18', '+1.07%', '13.25M', '17.27M', '70.263B', '21.51', '-22.83%', '15.82\n23.63']
# ['CCL', 'Carnival Corporation & plc', '', '25.76', '+0.40', '+1.58%', '13.158M', '21.199M', '34.928B', '13.42', '+0.92%', '15.07\n32.80']
# ['PBR', 'Petróleo Brasileiro S.A. - Petrobras', '', '13.13', '+0.01', '+0.08%', '13.083M', '23.11M', '84.615B', '5.44', '-7.67%', '11.03\n15.10']
# ['PATH', 'UiPath Inc.', '', '13.74', '+0.22', '+1.63%', '12.873M', '22.369M', '7.351B', '380.22', '+5.96%', '9.38\n18.74']
# ['NCLH', 'Norwegian Cruise Line Holdings Ltd.', '', '17.84', '+0.31', '+1.77%', '12.678M', '16.259M', '8.122B', '13.09', '-33.45%', '14.21\n29.29']
# ['KMI', 'Kinder Morgan, Inc.', '', '27.09', '-0.05', '-0.18%', '12.345M', '13.615M', '60.269B', '22.47', '-3.35%', '23.94\n31.48']
# ['WFC', 'Wells Fargo & Company', '', '83.86', '+0.44', '+0.53%', '12.277M', '14.702M', '268.641B', '14.01', '+13.60%', '58.42\n88.64']
# ['LYG', 'Lloyds Banking Group plc', '', '4.72', '+0.02', '+0.43%', '12.161M', '6.816M', '85.035B', '16.17', '+68.46%', '2.56\n5.05']
# ['BE', 'Bloom Energy Corporation', '', '104.97', '-2.14', '-2.00%', '11.925M', '14.099M', '24.827B', '1,697.31', '+350.99%', '15.15\n147.86']
# ['BRBR', 'BellRing Brands, Inc.', '', '26.26', '+0.64', '+2.50%', '11.843M', '3.127M', '3.335B', '15.39', '-65.03%', '25.40\n80.67']
# ['CSX', 'CSX Corporation', '', '33.99', '-0.02', '-0.06%', '11.8M', '17.011M', '63.367B', '22.67', '-1.71%', '26.22\n37.25']
# ['XOM', 'Exxon Mobil Corporation', '', '119.03', '+1.35', '+1.15%', '11.569M', '14.682M', '507.454B', '17.32', '-0.80%', '97.80\n123.21']
# ['OSCR', 'Oscar Health, Inc.', '', '14.71', '+0.46', '+3.23%', '11.343M', '17.302M', '4.236B', '--', '-20.88%', '11.20\n23.80']
# ['BABA', 'Alibaba Group Holding Limited', '', '159.72', '+2.01', '+1.27%', '11.331M', '19.477M', '381.091B', '17.68', '+81.05%', '80.06\n192.67']
# ['SHOP', 'Shopify Inc.', '', '140.45', '+0.52', '+0.37%', '11.245M', '7.885M', '182.844B', '107.75', '+33.79%', '69.84\n182.19']
# ['STLA', 'Stellantis N.V.', '', '9.74', '-0.24', '-2.40%', '11.141M', '16.402M', '28.136B', '--', '-23.52%', '8.39\n14.28']
# ['TSM', 'Taiwan Semiconductor Manufacturing Company Limited', '', '277.91', '-4.10', '-1.45%', '11.112M', '12.876M', '1.441T', '23.59', '+48.68%', '134.25\n311.37']
# ['HL', 'Hecla Mining Company', '', '14.06', '+0.08', '+0.57%', '10.984M', '23.707M', '9.422B', '47.16', '+145.26%', '4.46\n16.10']
# ['JD', 'JD.com, Inc.', '', '29.45', '-0.09', '-0.30%', '10.944M', '16.31M', '43.451B', '9.78', '-16.06%', '29.01\n46.45']
# ['MP', 'MP Materials Corp.', '', '58.51', '+1.53', '+2.69%', '10.93M', '14.715M', '10.369B', '--', '+216.20%', '15.56\n100.25']
# ['TU', 'TELUS Corporation', '', '13.58', '-0.70', '-4.90%', '10.818M', '4.22M', '21.022B', '26.27', '-7.87%', '13.24\n16.74']
# ['DOW', 'Dow Inc.', '', '21.85', '+0.18', '+0.83%', '10.757M', '13.334M', '15.53B', '--', '-50.36%', '20.40\n46.35']
# ['OKLO', 'Oklo Inc.', '', '96.63', '+1.27', '+1.33%', '10.744M', '19.498M', '15.103B', '--', '+337.43%', '17.14\n193.84']
# ['COMP', 'Compass, Inc.', '', '9.35', '-0.03', '-0.32%', '10.742M', '11.686M', '5.341B', '--', '+48.89%', '5.10\n10.25']
# ['ERIC', 'Telefonaktiebolaget LM Ericsson (publ)', '', '9.50', '-0.13', '-1.35%', '10.732M', '15.127M', '31.666B', '12.60', '+15.88%', '6.64\n10.35']
# ['ANET', 'Arista Networks Inc', '', '123.45', '-3.81', '-2.99%', '10.375M', '8.696M', '155.459B', '49.96', '+34.77%', '59.43\n164.94']
# ['PINS', 'Pinterest, Inc.', '', '25.77', '+0.25', '+0.98%', '10.341M', '12.138M', '17.546B', '9.24', '-14.05%', '23.68\n40.90']
# ['TMC', 'TMC the metals company Inc.', '', '5.42', '+0.53', '+10.95%', '10.309M', '9.304M', '2.899B', '--', '+434.46%', '0.72\n11.35']
# ['JNJ', 'Johnson & Johnson', '', '200.00', '+0.42', '+0.21%', '10.26M', '8.33M', '481.859B', '18.93', '+30.44%', '140.68\n200.28']
# ['COIN', 'Coinbase Global, Inc.', '', '261.79', '-2.16', '-0.82%', '10.184M', '9.298M', '70.587B', '24.73', '-18.68%', '142.58\n444.65']
# ['KO', 'The Coca-Cola Company', '', '71.22', '+0.54', '+0.76%', '10.168M', '16.345M', '306.744B', '23.57', '+12.93%', '60.62\n74.38']
# ['AG', 'First Majestic Silver Corp.', '', '11.70', '+0.15', '+1.30%', '10.044M', '21.335M', '5.737B', '76.10', '+73.42%', '5.09\n15.69']
# ['LRCX', 'Lam Research Corporation', '', '143.24', '-4.22', '-2.86%', '10.005M', '11.362M', '180.63B', '32.72', '+110.15%', '56.32\n167.15']
# ['CCC', 'CCC Intelligent Solutions Holdings Inc.', '', '7.19', '+0.17', '+2.42%', '9.994M', '6.312M', '4.683B', '--', '-40.41%', '7.00\n12.88']
# ['CX', 'CEMEX, S.A.B. de C.V.', '', '10.21', '+0.21', '+2.10%', '9.983M', '10.12M', '14.813B', '16.33', '+83.82%', '4.89\n10.56']
# ['KDP', 'Keurig Dr Pepper Inc.', '', '27.42', '+0.46', '+1.71%', '9.942M', '21.041M', '37.252B', '23.43', '-14.47%', '25.03\n36.12']
# ['UUUU', 'Energy Fuels Inc.', '', '15.05', '+0.09', '+0.60%', '9.876M', '23.289M', '3.568B', '--', '+106.92%', '3.20\n27.33']
# ['NKE', 'NIKE, Inc.', '', '62.49', '-0.41', '-0.65%', '9.864M', '14.539M', '92.373B', '32.94', '-14.90%', '52.28\n82.44']
# ['OBDC', 'Blue Owl Capital Corporation', '', '11.75', '-0.11', '-0.93%', '9.827M', '4.532M', '6.005B', '8.56', '-21.09%', '11.79\n15.73']
# ['CWAN', 'Clearwater Analytics Holdings, Inc.', '', '20.83', '+0.86', '+4.31%', '9.803M', '5.031M', '6.783B', '13.74', '-35.20%', '15.74\n32.71']
# ['DIS', 'The Walt Disney Company', '', '106.29', '+0.60', '+0.57%', '9.747M', '8.745M', '191.102B', '15.45', '-5.99%', '80.10\n124.69']
# ['HPQ', 'HP Inc.', '', '22.71', '-0.16', '-0.70%', '9.6M', '11.09M', '21.331B', '8.89', '-37.97%', '21.21\n39.80']
# ['PR', 'Permian Resources Corporation', '', '13.83', '+0.15', '+1.10%', '9.598M', '12.212M', '11.653B', '12.15', '-9.58%', '10.01\n16.33']
# ['SBET', 'SharpLink Gaming, Inc.', '', '10.55', '+0.26', '+2.53%', '9.563M', '19.359M', '2.075B', '--', '+29.92%', '2.28\n124.12']
# ['LCID', 'Lucid Group, Inc.', '', '12.97', '+0.06', '+0.43%', '9.555M', '10.619M', '4.203B', '--', '-38.52%', '12.57\n36.40']
# ['DELL', 'Dell Technologies Inc.', '', '122.69', '+0.21', '+0.17%', '9.513M', '7.23M', '82.493B', '19.47', '-9.87%', '66.25\n168.08']
# ['CAG', 'Conagra Brands, Inc.', '', '17.38', '+0.26', '+1.52%', '9.433M', '11.609M', '8.314B', '9.86', '-35.35%', '16.60\n28.69']
# ['IBRX', 'ImmunityBio, Inc.', '', '2.10', '+0.07', '+3.45%', '9.418M', '9.451M', '2.068B', '--', '-62.06%', '1.83\n5.43']
# ['HLN', 'Haleon plc', '', '9.61', '-0.07', '-0.72%', '9.39M', '9.041M', '43.017B', '22.10', '+2.11%', '8.71\n11.42']
# ['PSKY', 'Paramount Skydance Corporation', '', '16.09', '+0.36', '+2.29%', '9.377M', '9.411M', '17.75B', '--', '+52.27%', '9.95\n20.86']
# ['VICI', 'VICI Properties Inc.', '', '29.57', '-0.56', '-1.86%', '9.326M', '8.992M', '31.605B', '11.54', '-6.49%', '27.98\n34.03']
# ['GENI', 'Genius Sports Limited', '', '9.03', '-0.44', '-4.65%', '9.308M', '5.124M', '2.156B', '--', '+3.72%', '8.15\n13.73']
# ['DKNG', 'DraftKings Inc.', '', '29.37', '+0.55', '+1.91%', '9.253M', '15.572M', '14.62B', '--', '-33.30%', '26.23\n53.61']
# ['AMAT', 'Applied Materials, Inc.', '', '225.12', '-3.59', '-1.57%', '9.213M', '8.227M', '179.34B', '26.10', '+35.08%', '123.74\n242.50']
# ['CNH', 'CNH Industrial N.V.', '', '9.51', '-0.25', '-2.56%', '9.165M', '12.258M', '11.895B', '21.03', '-11.83%', '9.00\n14.27']
# ['FIG', 'Figma, Inc.', '', '36.76', '-0.62', '-1.66%', '9.077M', '10.323M', '18.218B', '--', '-67.64%', '36.56\n142.92']
# ['TOST', 'Toast, Inc.', '', '33.74', '-0.97', '-2.79%', '9.053M', '8.368M', '19.839B', '84.24', '-18.33%', '28.12\n49.66']
# ['HD', 'The Home Depot, Inc.', '', '336.48', '-21.55', '-6.02%', '8.998M', '3.458M', '334.798B', '24.63', '-11.99%', '326.31\n439.37']
# ['PTEN', 'Patterson-UTI Energy, Inc.', '', '5.79', '0.00', '0.00%', '8.923M', '8.781M', '2.23B', '--', '-28.61%', '5.10\n9.57']
# ['C', 'Citigroup Inc.', '', '98.32', '+0.13', '+0.13%', '8.91M', '13.116M', '247.432B', '14.11', '+43.13%', '55.51\n105.59']
# ['TGT', 'Target Corporation', '', '88.53', '+0.05', '+0.06%', '8.841M', '8.211M', '40.228B', '10.48', '-43.28%', '85.36\n158.42']
# ['KGC', 'Kinross Gold Corporation', '', '25.36', '+0.42', '+1.68%', '8.812M', '15.321M', '31.003B', '17.82', '+149.40%', '8.99\n27.84']
# ['TEVA', 'Teva Pharmaceutical Industries Limited', '', '24.84', '+0.25', '+1.02%', '8.755M', '11.273M', '28.498B', '--', '+46.28%', '12.47\n26.38']
# ['QCOM', 'QUALCOMM Incorporated', '', '165.06', '-1.69', '-1.01%', '8.724M', '9.577M', '178.1B', '34.73', '+1.24%', '120.80\n205.95']
# ['WDC', 'Western Digital Corporation', '', '152.86', '-9.59', '-5.90%', '8.722M', '9.509M', '52.4B', '22.06', '+229.18%', '28.83\n178.45']
# ['UEC', 'Uranium Energy Corp.', '', '11.45', '+0.23', '+2.05%', '8.669M', '15.906M', '5.532B', '--', '+30.47%', '3.85\n17.80']
# ['ASTS', 'AST SpaceMobile, Inc.', '', '58.22', '+1.62', '+2.86%', '8.635M', '12.397M', '21.368B', '--', '+116.53%', '17.50\n102.79']
# ['CVE', 'Cenovus Energy Inc.', '', '18.52', '+0.55', '+3.06%', '8.582M', '17.449M', '35.061B', '14.81', '+11.96%', '10.23\n18.61']
# ['GT', 'The Goodyear Tire & Rubber Company', '', '7.86', '+0.43', '+5.79%', '8.554M', '8.334M', '2.249B', '--', '-18.53%', '6.51\n12.03']
# ['TTD', 'The Trade Desk, Inc.', '', '40.47', '+0.26', '+0.65%', '8.496M', '14.165M', '19.788B', '47.62', '-66.33%', '39.75\n141.53']
# ['NEE', 'NextEra Energy, Inc.', '', '84.64', '-1.11', '-1.29%', '8.395M', '9.928M', '176.272B', '26.62', '+11.25%', '61.72\n87.53']
# ['PG', 'The Procter & Gamble Company', '', '146.99', '+1.17', '+0.80%', '8.351M', '7.469M', '344.028B', '21.55', '-14.61%', '144.09\n180.43']
# ['BAX', 'Baxter International Inc.', '', '18.15', '+0.38', '+2.14%', '8.329M', '7.065M', '9.33B', '--', '-45.36%', '17.47\n37.74']
# ['UNH', 'UnitedHealth Group Incorporated', '', '313.58', '-6.94', '-2.17%', '8.279M', '10.904M', '284.053B', '16.75', '-44.45%', '234.60\n622.83']
# ['CPNG', 'Coupang, Inc.', '', '27.64', '-0.17', '-0.61%', '8.238M', '11.288M', '50.489B', '135.80', '+14.96%', '19.02\n34.08']
# ['BB', 'BlackBerry Limited', '', '4.30', '+0.14', '+3.37%', '8.108M', '9.935M', '2.567B', '129.61', '+77.02%', '2.29\n6.24']
# ['DVN', 'Devon Energy Corporation', '', '35.87', '+0.80', '+2.28%', '8.099M', '7.499M', '22.77B', '8.44', '-7.49%', '25.89\n39.65']
# ['KLAR', 'Klarna Group plc', '', '31.63', '-3.25', '-9.32%', '8.09M', '3.274M', '11.95B', '--', '-18.39%', '33.31\n47.48']
# ['NET', 'Cloudflare, Inc.', '', '196.53', '-5.72', '-2.83%', '7.966M', '2.505M', '68.841B', '--', '+109.87%', '89.42\n260.00']
# ['GLXY', 'Galaxy Digital', '', '25.58', '+0.54', '+2.16%', '7.937M', '9.025M', '10.331B', '--', '+9.82%', '17.40\n45.92']
# ['AVTR', 'Avantor, Inc.', '', '11.14', '+0.26', '+2.39%', '7.905M', '11.182M', '7.595B', '--', '-44.83%', '10.83\n23.32']
# ['BP', 'BP p.l.c.', '', '36.69', '+0.19', '+0.52%', '7.807M', '6.703M', '93.779B', '64.15', '+25.47%', '25.22\n37.64']
# ['DJT', 'Trump Media & Technology Group Corp.', '', '10.77', '-0.08', '-0.74%', '7.8M', '6.503M', '3.016B', '--', '-63.68%', '10.47\n43.46']
# ['WSC', 'WillScot Holdings Corporation', '', '15.40', '-0.86', '-5.29%', '7.742M', '2.553M', '2.804B', '14.64', '-53.73%', '16.20\n39.81']
# ['YMM', 'Full Truck Alliance Co. Ltd.', '', '10.95', '+0.10', '+0.92%', '7.738M', '8.272M', '11.453B', '--', '+26.60%', '8.36\n14.07']
# ['EQX', 'Equinox Gold Corp.', '', '12.60', '+0.15', '+1.20%', '7.685M', '15.362M', '9.888B', '111.78', '+126.78%', '4.95\n13.53']
# ['ARCC', 'Ares Capital Corporation', '', '19.52', '-0.16', '-0.81%', '7.67M', '5.123M', '13.971B', '10.14', '-9.85%', '18.26\n23.84']
# ['BSX', 'Boston Scientific Corporation', '', '99.22', '-2.54', '-2.50%', '7.658M', '8.903M', '147.088B', '54.92', '+12.65%', '85.98\n109.50']
# ['PL', 'Planet Labs PBC', '', '11.45', '+0.24', '+2.14%', '7.644M', '12.576M', '3.526B', '--', '+252.52%', '2.79\n16.78']
# ['UWMC', 'UWM Holdings Corporation', '', '4.96', '+0.06', '+1.22%', '7.629M', '9.434M', '8.175B', '87.18', '-21.47%', '3.80\n7.14']
# ['TXN', 'Texas Instruments Incorporated', '', '157.32', '+2.33', '+1.50%', '7.549M', '7.649M', '143.025B', '29.02', '-22.92%', '139.95\n221.69']
# ['HNGE', 'Hinge Health, Inc.', '', '40.62', '-0.22', '-0.54%', '7.536M', '1.226M', '3.198B', '--', '+8.73%', '33.42\n62.18']
# ['BA', 'The Boeing Company', '', '189.63', '-2.18', '-1.14%', '7.469M', '7.763M', '144.137B', '--', '+31.74%', '128.88\n242.69']
# ['ASX', 'ASE Technology Holding Co., Ltd.', '', '14.17', '-0.13', '-0.91%', '7.443M', '7.713M', '30.913B', '28.63', '+45.03%', '6.94\n16.39']
# ['MDLZ', 'Mondelez International, Inc.', '', '55.78', '+0.21', '+0.38%', '7.438M', '7.841M', '72.176B', '21.12', '-13.00%', '53.95\n71.15']
# ['RUN', 'Sunrun Inc.', '', '19.22', '+0.65', '+3.50%', '7.412M', '9.996M', '4.46B', '--', '+91.25%', '5.38\n22.44']
# ['PTON', 'Peloton Interactive, Inc.', '', '7.11', '-0.03', '-0.42%', '7.401M', '12.224M', '2.971B', '--', '-10.08%', '4.63\n10.90']
# ['MRNA', 'Moderna, Inc.', '', '24.92', '+0.16', '+0.65%', '7.361M', '11.359M', '9.737B', '--', '-33.60%', '23.04\n48.92']
# ['V', 'Visa Inc.', '', '321.18', '-4.57', '-1.40%', '7.348M', '5.848M', '623.392B', '32.35', '+4.46%', '299.00\n375.51']
# ['NXE', 'NexGen Energy Ltd.', '', '8.02', '+0.10', '+1.26%', '7.34M', '9.897M', '5.25B', '--', '-6.49%', '3.91\n9.95']
# ['EXK', 'Endeavour Silver Corp.', '', '7.59', '+0.07', '+0.93%', '7.337M', '14.199M', '2.233B', '--', '+52.23%', '2.95\n10.37']
# ['VG', 'Venture Global, Inc.', '', '7.90', '-0.21', '-2.59%', '7.223M', '9.038M', '19.34B', '10.15', '-66.21%', '6.75\n24.00']
# ['BTDR', 'Bitdeer Technologies Group', '', '10.71', '+0.08', '+0.75%', '7.204M', '7.443M', '2.375B', '--', '-7.89%', '6.84\n27.80']
# ['BBWI', 'Bath & Body Works, Inc.', '', '21.10', '-0.35', '-1.63%', '7.138M', '6.661M', '4.465B', '6.50', '-29.53%', '21.37\n41.87']
# ['D', 'Dominion Energy, Inc.', '', '61.45', '-0.05', '-0.08%', '7.122M', '4.742M', '52.473B', '19.74', '+6.79%', '48.07\n62.52']
# ['OXY', 'Occidental Petroleum Corporation', '', '42.52', '+0.83', '+1.99%', '7.019M', '10.218M', '41.891B', '30.75', '-17.45%', '34.78\n53.20']
# ['MO', 'Altria Group, Inc.', '', '58.94', '+0.81', '+1.39%', '7.007M', '8.295M', '99.013B', '11.10', '+4.06%', '50.08\n68.60']
# ['BCS', 'Barclays PLC', '', '21.09', '-0.07', '-0.33%', '6.998M', '7.296M', '73.981B', '10.27', '+61.77%', '12.14\n22.64']
# ['KR', 'The Kroger Co.', '', '67.38', '+1.28', '+1.94%', '6.972M', '6.88M', '44.651B', '17.01', '+13.77%', '57.08\n74.90']
# ['PRMB', 'Primo Brands Corporation', '', '15.53', '-0.11', '-0.70%', '6.953M', '6.255M', '5.801B', '--', '-44.73%', '14.36\n35.85']
# ['CZR', 'Caesars Entertainment, Inc.', '', '20.35', '-0.26', '-1.26%', '6.947M', '8.891M', '4.233B', '--', '-44.86%', '18.25\n40.00']
# ['VRT', 'Vertiv Holdings Co', '', '164.86', '-1.79', '-1.07%', '6.918M', '7.423M', '63.032B', '64.46', '+18.24%', '53.60\n202.45']
# ['CNC', 'Centene Corporation', '', '36.93', '-0.15', '-0.40%', '6.903M', '11.979M', '18.152B', '--', '-35.86%', '25.08\n66.81']
# ['HUT', 'Hut 8 Corp.', '', '38.67', '+0.97', '+2.57%', '6.853M', '7.401M', '4.178B', '19.72', '+48.89%', '10.04\n57.29']
# ['AES', 'The AES Corporation', '', '13.72', '-0.20', '-1.44%', '6.848M', '10.202M', '9.77B', '9.12', '+1.24%', '9.46\n15.51']
# ['SCHW', 'The Charles Schwab Corporation', '', '92.28', '+0.37', '+0.40%', '6.824M', '8.95M', '167.508B', '22.11', '+14.62%', '65.88\n99.59']
# ['HAL', 'Halliburton Company', '', '26.79', '+0.17', '+0.64%', '6.821M', '12.752M', '22.841B', '18.01', '-12.64%', '18.72\n32.57']
# ['BKR', 'Baker Hughes Company', '', '48.06', '+0.18', '+0.38%', '6.768M', '6.76M', '47.424B', '16.78', '+11.69%', '33.60\n50.93']
# ['TME', 'Tencent Music Entertainment Group', '', '18.70', '-0.20', '-1.06%', '6.748M', '5.754M', '31.495B', '19.37', '+69.51%', '10.26\n26.70']
# ['TJX', 'The TJX Companies, Inc.', '', '145.58', '+0.40', '+0.28%', '6.734M', '4.974M', '162.411B', '33.26', '+21.43%', '112.10\n148.11']
# ['CNQ', 'Canadian Natural Resources Limited', '', '34.05', '+0.72', '+2.16%', '6.698M', '6.973M', '70.979B', '14.87', '-1.01%', '24.65\n34.98']
# ['MCHP', 'Microchip Technology Incorporated', '', '50.87', '-0.83', '-1.61%', '6.697M', '7.72M', '27.493B', '--', '-20.31%', '34.13\n77.20']
# ['XYZ', 'Block, Inc.', '', '57.64', '-1.25', '-2.12%', '6.624M', '6.302M', '35.136B', '12.09', '-36.28%', '44.27\n99.26']
# ['BIDU', 'Baidu, Inc.', '', '117.14', '+3.03', '+2.66%', '6.534M', '5.709M', '40.836B', '10.57', '+32.66%', '74.71\n149.51']
# ['VLY', 'Valley National Bancorp', '', '10.46', '+0.03', '+0.29%', '6.53M', '10.695M', '5.855B', '12.29', '+2.36%', '7.48\n11.35']
# ['RITM', 'Rithm Capital Corp.', '', '10.87', '+0.01', '+0.09%', '6.526M', '6.103M', '6.024B', '7.67', '+1.88%', '9.13\n12.74']
# ['AEG', 'Aegon Ltd.', '', '7.51', '-0.12', '-1.57%', '6.508M', '4.791M', '11.883B', '8.50', '+20.54%', '5.42\n8.15']
# ['USB', 'U.S. Bancorp', '', '45.92', '+0.45', '+0.99%', '6.502M', '9.163M', '71.46B', '10.78', '-9.78%', '35.18\n53.98']
# ['CRM', 'Salesforce, Inc.', '', '233.50', '-3.53', '-1.49%', '6.495M', '8.845M', '223.226B', '35.41', '-26.71%', '226.48\n369.00']
# ['MPW', 'Medical Properties Trust, Inc.', '', '5.10', '-0.04', '-0.78%', '6.406M', '8.519M', '3.068B', '--', '+18.71%', '3.51\n6.34']
# ['U', 'Unity Software Inc.', '', '37.00', '+0.33', '+0.90%', '6.339M', '10.824M', '15.833B', '--', '+85.20%', '15.33\n46.94']
# ['EXC', 'Exelon Corporation', '', '46.38', '-0.22', '-0.47%', '6.334M', '6.537M', '46.843B', '16.46', '+19.18%', '35.94\n48.51']
# ['STNE', 'StoneCo Ltd.', '', '16.00', '-0.15', '-0.93%', '6.317M', '4.982M', '4.28B', '--', '+74.03%', '7.72\n19.95']
# ['USAR', 'USA Rare Earth, Inc.', '', '15.26', '+0.81', '+5.61%', '6.297M', '13.113M', '2.024B', '--', '+34.79%', '5.56\n43.98']
# ['FHN', 'First Horizon Corporation', '', '20.76', '+0.17', '+0.83%', '6.202M', '12.529M', '10.541B', '12.93', '+2.39%', '15.19\n23.70']
# ['SIRI', 'Sirius XM Holdings Inc.', '', '20.91', '-0.19', '-0.90%', '6.175M', '3.418M', '7.041B', '7.61', '-16.17%', '18.69\n29.18']
# ['IAG', 'IAMGOLD Corporation', '', '13.68', '+0.19', '+1.41%', '6.122M', '13.598M', '7.9B', '23.36', '+143.50%', '4.98\n14.68']
# ['CVS', 'CVS Health Corporation', '', '77.94', '-0.47', '-0.60%', '6.12M', '7.337M', '98.94B', '209.87', '+40.60%', '43.56\n85.15']
# ['TSCO', 'Tractor Supply Company', '', '53.53', '-0.15', '-0.28%', '6.117M', '4.742M', '28.285B', '26.79', '-1.63%', '46.85\n63.99']
# ['PEP', 'PepsiCo, Inc.', '', '148.77', '+0.94', '+0.64%', '6.048M', '7.557M', '203.678B', '27.74', '-5.67%', '127.60\n165.13']
# ['ZETA', 'Zeta Global Holdings Corp.', '', '17.34', '+0.04', '+0.23%', '6.043M', '7.82M', '4.128B', '--', '-21.44%', '10.69\n27.79']
# ['KMB', 'Kimberly-Clark Corporation', '', '103.25', '-0.41', '-0.40%', '6.028M', '3.92M', '34.264B', '17.58', '-23.56%', '99.22\n150.45']
# ['FSM', 'Fortuna Mining Corp.', '', '8.31', '+0.07', '+0.85%', '5.97M', '17.519M', '2.555B', '9.98', '+70.60%', '4.13\n9.82']
# ['JPM', 'JPMorgan Chase & Co.', '', '299.41', '-0.96', '-0.32%', '5.969M', '8.089M', '1.006T', '15.04', '+23.56%', '202.16\n322.25']
# ['WIT', 'Wipro Limited', '', '2.63', '0.00', '0.00%', '5.961M', '7.649M', '28.706B', '19.03', '-22.76%', '2.55\n3.79']
# ['ONON', 'On Holding AG', '', '42.66', '+1.26', '+3.04%', '5.895M', '6.77M', '14.085B', '49.95', '-22.47%', '34.38\n64.05']
# ['CRBG', 'Corebridge Financial, Inc.', '', '27.61', '-0.22', '-0.79%', '5.874M', '4.152M', '13.926B', '16.35', '-8.54%', '23.69\n36.57']
# ['DASH', 'DoorDash, Inc.', '', '212.08', '+1.43', '+0.68%', '5.865M', '3.941M', '91.406B', '108.38', '+19.57%', '155.40\n285.50']
# ['UMC', 'United Microelectronics Corporation', '', '7.06', '+0.04', '+0.57%', '5.85M', '7.019M', '17.728B', '13.87', '+0.57%', '5.61\n8.33']
# ['ENPH', 'Enphase Energy, Inc.', '', '27.60', '+0.07', '+0.25%', '5.828M', '8.036M', '3.612B', '19.90', '-55.13%', '27.36\n78.26']
# ['CVX', 'Chevron Corporation', '', '153.62', '+0.51', '+0.33%', '5.818M', '7.454M', '309.477B', '22.22', '-2.99%', '132.04\n168.96']
# ['GILD', 'Gilead Sciences, Inc.', '', '127.18', '+3.09', '+2.49%', '5.809M', '7.013M', '157.806B', '19.46', '+41.41%', '86.08\n127.68']
# ['PBR-A', 'Petróleo Brasileiro S.A. - Petrobras', '', '12.42', '+0.07', '+0.57%', '5.769M', '7.426M', '83.423B', '5.44', '-5.65%', '10.28\n13.74']
# ['DAL', 'Delta Air Lines, Inc.', '', '57.13', '+1.37', '+2.46%', '5.751M', '8.281M', '37.304B', '8.98', '-13.88%', '34.74\n69.98']
# ['FLNC', 'Fluence Energy, Inc.', '', '17.02', '-0.21', '-1.22%', '5.736M', '7.282M', '3.106B', '--', '-18.30%', '3.46\n24.00']
# ['AA', 'Alcoa Corporation', '', '36.55', '+0.77', '+2.15%', '5.73M', '6.664M', '9.465B', '8.72', '-21.54%', '21.53\n47.77']
# ['WU', 'The Western Union Company', '', '8.73', '-0.17', '-1.91%', '5.715M', '10.628M', '2.82B', '3.81', '-17.21%', '7.85\n11.95']
# ['FLEX', 'Flex Ltd.', '', '57.57', '-1.18', '-2.01%', '5.707M', '3.734M', '21.529B', '26.32', '+57.38%', '25.11\n67.00']
# ['APH', 'Amphenol Corporation', '', '132.44', '+0.11', '+0.08%', '5.69M', '8.449M', '162.114B', '44.58', '+86.43%', '56.45\n144.37']
# ['AZN', 'AstraZeneca PLC', '', '89.55', '+0.15', '+0.17%', '5.68M', '4.696M', '277.653B', '29.59', '+40.13%', '61.24\n90.27']
# ['NEM', 'Newmont Corporation', '', '86.60', '-0.49', '-0.56%', '5.675M', '11.365M', '95.126B', '13.66', '+101.69%', '36.86\n98.58']
# ['SBUX', 'Starbucks Corporation', '', '83.33', '-0.36', '-0.43%', '5.65M', '9.742M', '94.738B', '38.18', '-14.91%', '75.50\n117.46']
# ['STUB', 'StubHub Holdings, Inc.', '', '11.99', '-0.82', '-6.44%', '5.637M', '5.432M', '4.412B', '--', '-41.73%', '12.50\n27.89']
# ['INVH', 'Invitation Homes Inc.', '', '27.54', '-0.50', '-1.78%', '5.585M', '4.533M', '16.883B', '29.88', '-17.60%', '27.38\n35.80']
# ['TECK', 'Teck Resources Limited', '', '39.08', '-1.32', '-3.27%', '5.572M', '5.23M', '19.13B', '23.23', '-14.28%', '28.32\n48.47']
# ['COTY', 'Coty Inc.', '', '3.31', '-0.04', '-1.19%', '5.54M', '8.415M', '2.895B', '--', '-52.75%', '3.34\n8.04']
# ['FE', 'FirstEnergy Corp.', '', '46.61', '+0.05', '+0.11%', '5.539M', '4.224M', '26.925B', '19.91', '+11.98%', '37.58\n48.20']
# ['ZTS', 'Zoetis Inc.', '', '118.14', '-0.66', '-0.56%', '5.53M', '3.271M', '52.358B', '20.35', '-32.33%', '117.26\n181.85']
# ['CPRT', 'Copart, Inc.', '', '41.32', '-0.01', '-0.02%', '5.489M', '7.467M', '39.991B', '25.84', '-26.88%', '39.58\n64.38']
# ['CELH', 'Celsius Holdings, Inc.', '', '40.64', '+0.48', '+1.20%', '5.415M', '6.22M', '10.476B', '340.44', '+47.16%', '21.10\n66.74']
# ['ON', 'ON Semiconductor Corporation', '', '45.56', '-0.46', '-1.00%', '5.414M', '8.33M', '19.03B', '62.15', '-30.95%', '31.04\n74.52']
# ['LITE', 'Lumentum Holdings Inc.', '', '247.43', '+5.36', '+2.21%', '5.413M', '3.89M', '17.546B', '149.03', '+193.49%', '45.65\n273.89']
# ['DXCM', 'DexCom, Inc.', '', '60.17', '+1.68', '+2.87%', '5.413M', '6.28M', '23.596B', '32.31', '-21.89%', '54.11\n93.25']
# ['MQ', 'Marqeta, Inc.', '', '4.78', '+0.06', '+1.27%', '5.401M', '4.294M', '2.143B', '--', '+21.03%', '3.48\n7.04']
# ['EQT', 'EQT Corporation', '', '58.75', '-0.29', '-0.49%', '5.383M', '7.705M', '36.664B', '20.61', '+33.94%', '42.27\n61.26']
# ['TFC', 'Truist Financial Corporation', '', '44.34', '+0.42', '+0.96%', '5.38M', '8.23M', '57.174B', '11.98', '-5.81%', '33.56\n49.06']
# ['CARR', 'Carrier Global Corporation', '', '52.01', '-1.12', '-2.11%', '5.351M', '6.159M', '44.262B', '34.29', '-28.52%', '52.95\n81.09']
# ['UPWK', 'Upwork Inc.', '', '17.08', '+0.89', '+5.50%', '5.303M', '3.038M', '2.265B', '9.49', '+8.44%', '11.13\n20.54']
# ['VTRS', 'Viatris Inc.', '', '10.71', '+0.05', '+0.47%', '5.301M', '9.245M', '12.364B', '--', '-18.31%', '6.85\n13.55']
# ['LOW', "Lowe's Companies, Inc.", '', '219.57', '-5.43', '-2.41%', '5.278M', '2.715M', '123.14B', '18.72', '-13.21%', '206.39\n280.64']
# ['S', 'SentinelOne, Inc.', '', '16.17', '+0.01', '+0.06%', '5.277M', '6.006M', '5.42B', '--', '-41.49%', '15.36\n29.29']
# ['HON', 'Honeywell International Inc.', '', '191.45', '-4.63', '-2.36%', '5.276M', '4.52M', '129.012B', '21.01', '-8.83%', '169.05\n227.82']
# ['DOC', 'Healthpeak Properties, Inc.', '', '17.69', '+0.40', '+2.31%', '5.272M', '8.006M', '12.294B', '--', '-19.21%', '16.63\n22.71']
# ['PPL', 'PPL Corporation', '', '36.49', '-0.31', '-0.84%', '5.265M', '4.943M', '26.993B', '25.00', '+7.79%', '31.22\n38.27']
# ['GAP', 'The Gap, Inc.', '', '23.85', '+0.08', '+0.34%', '5.255M', '9.802M', '8.898B', '10.41', '+13.19%', '16.99\n29.29']
# ['UPS', 'United Parcel Service, Inc.', '', '92.83', '-1.36', '-1.44%', '5.254M', '7.984M', '78.756B', '14.83', '-29.29%', '82.00\n138.67']
# ['MUFG', 'Mitsubishi UFJ Financial Group, Inc.', '', '15.16', '-0.26', '-1.69%', '5.205M', '3.231M', '177.026B', '21.83', '+30.02%', '10.46\n16.24']
# ['ABT', 'Abbott Laboratories', '', '130.00', '-0.03', '-0.02%', '5.185M', '5.683M', '226.26B', '16.40', '+11.01%', '110.86\n141.23']
# ['BKD', 'Brookdale Senior Living Inc.', '', '10.57', '+0.08', '+0.76%', '5.184M', '3.099M', '2.512B', '--', '+101.73%', '4.45\n11.00']
# ['HBM', 'Hudbay Minerals Inc.', '', '15.11', '-0.22', '-1.44%', '5.152M', '6.997M', '5.986B', '13.59', '+68.46%', '5.95\n17.73']
# ['TERN', 'Terns Pharmaceuticals, Inc.', '', '27.56', '+2.00', '+7.82%', '5.148M', '2.394M', '2.483B', '--', '+332.49%', '1.87\n26.12']
# ['FAST', 'Fastenal Company', '', '39.96', '+0.26', '+0.65%', '5.13M', '6.407M', '45.876B', '37.83', '-2.68%', '35.31\n50.63']
# ['COLD', 'Americold Realty Trust, Inc.', '', '10.81', '-0.07', '-0.64%', '5.117M', '6.305M', '3.089B', '--', '-50.88%', '10.50\n24.22']
# ['SHEL', 'Shell plc', '', '75.31', '-0.09', '-0.12%', '5.111M', '4.018M', '215.926B', '15.55', '+14.57%', '58.55\n77.47']
# ['STM', 'STMicroelectronics N.V.', '', '22.34', '-0.40', '-1.76%', '5.105M', '6.092M', '19.884B', '40.70', '-7.33%', '17.25\n33.47']
# ['FITB', 'Fifth Third Bancorp', '', '41.34', '+0.22', '+0.54%', '5.093M', '6.911M', '27.326B', '12.70', '-11.46%', '32.25\n49.07']
# ['GLW', 'Corning Incorporated', '', '80.12', '-0.94', '-1.16%', '5.071M', '7.936M', '68.692B', '52.64', '+71.41%', '37.31\n92.57']
# ['LUV', 'Southwest Airlines Co.', '', '31.96', '+0.11', '+0.35%', '5.059M', '9.012M', '16.785B', '49.35', '-1.58%', '23.82\n37.96']
# ['BTI', 'British American Tobacco p.l.c.', '', '54.86', '+0.15', '+0.27%', '5.058M', '4.149M', '119.367B', '29.58', '+48.15%', '34.82\n59.29']
# ['ASAN', 'Asana, Inc.', '', '12.09', '+0.06', '+0.50%', '5.046M', '3.819M', '2.856B', '--', '-12.70%', '11.58\n27.77']
# ['GIS', 'General Mills, Inc.', '', '47.69', '+0.72', '+1.53%', '5.036M', '6.013M', '25.499B', '9.00', '-25.18%', '45.80\n67.40']
# ['PANW', 'Palo Alto Networks, Inc.', '', '201.00', '-1.90', '-0.94%', '5.001M', '5.776M', '137.481B', '128.28', '+4.57%', '144.15\n223.61']
# the "next" button is not clickable as we have gone through all pages.

# %%
len(data)
# Out:
# 315

# %%
stocks_df = pd.DataFrame(data)
stocks_df
# Out:
#                                 name symbol   price  change   volumn  \
# 0        Olema Pharmaceuticals, Inc.   OLMA   20.14  +11.62  85.927M
# 1               The Home Depot, Inc.     HD  336.48  -21.55   9.079M
# 2       Warner Bros. Discovery, Inc.    WBD   23.69   +0.95  58.421M
# 3              Microsoft Corporation   MSFT  493.79  -13.70  32.649M
# 4                   Cloudflare, Inc.    NET  196.53   -5.72   8.033M
# ..                               ...    ...     ...     ...      ...
# 310           Southwest Airlines Co.    LUV   31.96   +0.11   5.059M
# 311  British American Tobacco p.l.c.    BTI   54.86   +0.15   5.058M
# 312                      Asana, Inc.   ASAN   12.09   +0.06   5.046M
# 313              General Mills, Inc.    GIS   47.69   +0.72   5.036M
# 314         Palo Alto Networks, Inc.   PANW  201.00   -1.90   5.001M
#
#     market_cap pe_ratio
# 0       1.383B       --
# 1     334.928B    22.86
# 2      58.703B   124.68
# 3        3.67T    35.12
# 4      68.841B       --
# ..         ...      ...
# 310    16.785B    49.35
# 311   119.367B    29.58
# 312     2.856B       --
# 313    25.499B     9.00
# 314   137.481B   128.28
#
# [315 rows x 7 columns]

# %%
stocks_df.info
# Out:
# <bound method DataFrame.info of                                 name symbol   price  change   volumn  \
# 0        Olema Pharmaceuticals, Inc.   OLMA   20.14  +11.62  85.927M
# 1               The Home Depot, Inc.     HD  336.48  -21.55   9.079M
# 2       Warner Bros. Discovery, Inc.    WBD   23.69   +0.95  58.421M
# 3              Microsoft Corporation   MSFT  493.79  -13.70  32.649M
# 4                   Cloudflare, Inc.    NET  196.53   -5.72   8.033M
# ..                               ...    ...     ...     ...      ...
# 310           Southwest Airlines Co.    LUV   31.96   +0.11   5.059M
# 311  British American Tobacco p.l.c.    BTI   54.86   +0.15   5.058M
# 312                      Asana, Inc.   ASAN   12.09   +0.06   5.046M
# 313              General Mills, Inc.    GIS   47.69   +0.72   5.036M
# 314         Palo Alto Networks, Inc.   PANW  201.00   -1.90   5.001M
#
#     market_cap pe_ratio
# 0       1.383B       --
# 1     334.928B    22.86
# 2      58.703B   124.68
# 3        3.67T    35.12
# 4      68.841B       --
# ..         ...      ...
# 310    16.785B    49.35
# 311   119.367B    29.58
# 312     2.856B       --
# 313    25.499B     9.00
# 314   137.481B   128.28
#
# [315 rows x 7 columns]>

# %%
stocks_df.describe
# Out:
# <bound method NDFrame.describe of                                 name symbol   price  change   volumn  \
# 0        Olema Pharmaceuticals, Inc.   OLMA   20.14  +11.62  85.927M
# 1               The Home Depot, Inc.     HD  336.48  -21.55   9.079M
# 2       Warner Bros. Discovery, Inc.    WBD   23.69   +0.95  58.421M
# 3              Microsoft Corporation   MSFT  493.79  -13.70  32.649M
# 4                   Cloudflare, Inc.    NET  196.53   -5.72   8.033M
# ..                               ...    ...     ...     ...      ...
# 310           Southwest Airlines Co.    LUV   31.96   +0.11   5.059M
# 311  British American Tobacco p.l.c.    BTI   54.86   +0.15   5.058M
# 312                      Asana, Inc.   ASAN   12.09   +0.06   5.046M
# 313              General Mills, Inc.    GIS   47.69   +0.72   5.036M
# 314         Palo Alto Networks, Inc.   PANW  201.00   -1.90   5.001M
#
#     market_cap pe_ratio
# 0       1.383B       --
# 1     334.928B    22.86
# 2      58.703B   124.68
# 3        3.67T    35.12
# 4      68.841B       --
# ..         ...      ...
# 310    16.785B    49.35
# 311   119.367B    29.58
# 312     2.856B       --
# 313    25.499B     9.00
# 314   137.481B   128.28
#
# [315 rows x 7 columns]>

# %%
stocks_df.apply(lambda col : col.str.strip() if col.dtype == 'object' else col)
# Out:
#                                 name symbol   price  change   volumn  \
# 0        Olema Pharmaceuticals, Inc.   OLMA   20.14  +11.62  85.927M
# 1               The Home Depot, Inc.     HD  336.48  -21.55   9.079M
# 2       Warner Bros. Discovery, Inc.    WBD   23.69   +0.95  58.421M
# 3              Microsoft Corporation   MSFT  493.79  -13.70  32.649M
# 4                   Cloudflare, Inc.    NET  196.53   -5.72   8.033M
# ..                               ...    ...     ...     ...      ...
# 310           Southwest Airlines Co.    LUV   31.96   +0.11   5.059M
# 311  British American Tobacco p.l.c.    BTI   54.86   +0.15   5.058M
# 312                      Asana, Inc.   ASAN   12.09   +0.06   5.046M
# 313              General Mills, Inc.    GIS   47.69   +0.72   5.036M
# 314         Palo Alto Networks, Inc.   PANW  201.00   -1.90   5.001M
#
#     market_cap pe_ratio
# 0       1.383B       --
# 1     334.928B    22.86
# 2      58.703B   124.68
# 3        3.67T    35.12
# 4      68.841B       --
# ..         ...      ...
# 310    16.785B    49.35
# 311   119.367B    29.58
# 312     2.856B       --
# 313    25.499B     9.00
# 314   137.481B   128.28
#
# [315 rows x 7 columns]

# %%
stocks_df.dtypes
# Out:
# name          object
# symbol        object
# price         object
# change        object
# volumn        object
# market_cap    object
# pe_ratio      object
# dtype: object

# %%
stocks_df['price']= stocks_df['price'].astype(float)

# %%
stocks_df.dtypes
# Out:
# name           object
# symbol         object
# price         float64
# change         object
# volumn         object
# market_cap     object
# pe_ratio       object
# dtype: object

# %%
import re

# %%
stocks_df['change'].str.extract(r'([^0-9.])')
# Out:
#      0
# 0    +
# 1    -
# 2    +
# 3    -
# 4    -
# ..  ..
# 310  +
# 311  +
# 312  +
# 313  +
# 314  -
#
# [315 rows x 1 columns]

# %%
stocks_df['change'] = stocks_df['change'].str.replace('+','')

# %%
stocks_df
# Out:
#                                 name symbol   price  change   volumn  \
# 0        Olema Pharmaceuticals, Inc.   OLMA   20.14   11.62  85.927M
# 1               The Home Depot, Inc.     HD  336.48  -21.55   9.079M
# 2       Warner Bros. Discovery, Inc.    WBD   23.69    0.95  58.421M
# 3              Microsoft Corporation   MSFT  493.79  -13.70  32.649M
# 4                   Cloudflare, Inc.    NET  196.53   -5.72   8.033M
# ..                               ...    ...     ...     ...      ...
# 310           Southwest Airlines Co.    LUV   31.96    0.11   5.059M
# 311  British American Tobacco p.l.c.    BTI   54.86    0.15   5.058M
# 312                      Asana, Inc.   ASAN   12.09    0.06   5.046M
# 313              General Mills, Inc.    GIS   47.69    0.72   5.036M
# 314         Palo Alto Networks, Inc.   PANW  201.00   -1.90   5.001M
#
#     market_cap pe_ratio
# 0       1.383B       --
# 1     334.928B    22.86
# 2      58.703B   124.68
# 3        3.67T    35.12
# 4      68.841B       --
# ..         ...      ...
# 310    16.785B    49.35
# 311   119.367B    29.58
# 312     2.856B       --
# 313    25.499B     9.00
# 314   137.481B   128.28
#
# [315 rows x 7 columns]

# %%
stocks_df.dtypes
# Out:
# name           object
# symbol         object
# price         float64
# change         object
# volumn         object
# market_cap     object
# pe_ratio       object
# dtype: object

# %%
stocks_df['change'] = stocks_df['change'].astype(float)

# %%
stocks_df.dtypes
# Out:
# name           object
# symbol         object
# price         float64
# change        float64
# volumn         object
# market_cap     object
# pe_ratio       object
# dtype: object

# %%
stocks_df['volumn'].unique()
# Out:
# array(['85.927M', '9.079M', '58.421M', '32.649M', '8.033M', '75.542M',
#        '65.744M', '64.447M', '64.003M', '58.147M', '56.968M', '55.466M',
#        '54.705M', '52.965M', '52.813M', '52.59M', '52.536M', '52.025M',
#        '50.583M', '49.063M', '46.565M', '46.056M', '45.301M', '43.511M',
#        '42.306M', '41.898M', '40.994M', '40.078M', '39.673M', '39.623M',
#        '38.855M', '38.721M', '37.811M', '35.705M', '35.114M', '35.082M',
#        '34.722M', '33.827M', '33.132M', '33.087M', '32.342M', '32.293M',
#        '31.801M', '31.755M', '31.73M', '28.739M', '28.635M', '28.394M',
#        '28.371M', '27.556M', '27.399M', '26.966M', '26.628M', '26.435M',
#        '26.306M', '25.98M', '25.598M', '25.193M', '24.903M', '24.857M',
#        '24.804M', '24.541M', '24.518M', '23.924M', '23.798M', '23.749M',
#        '23.72M', '23.453M', '23.29M', '22.874M', '22.683M', '22.255M',
#        '21.252M', '20.647M', '20.565M', '20.29M', '20.244M', '20.095M',
#        '20.073M', '19.606M', '19.1M', '18.996M', '18.501M', '18.47M',
#        '18.165M', '18.026M', '17.872M', '17.633M', '16.973M', '16.835M',
#        '16.72M', '16.555M', '16.528M', '16.521M', '16.484M', '16.163M',
#        '16.162M', '15.863M', '15.752M', '15.096M', '15.06M', '14.859M',
#        '14.778M', '14.69M', '14.58M', '14.457M', '14.328M', '14.116M',
#        '13.946M', '13.788M', '13.613M', '13.577M', '13.412M', '13.25M',
#        '13.158M', '13.083M', '12.873M', '12.678M', '12.345M', '12.277M',
#        '12.161M', '11.925M', '11.843M', '11.8M', '11.569M', '11.343M',
#        '11.331M', '11.245M', '11.141M', '11.112M', '10.984M', '10.944M',
#        '10.93M', '10.818M', '10.757M', '10.744M', '10.742M', '10.732M',
#        '10.375M', '10.341M', '10.309M', '10.26M', '10.184M', '10.168M',
#        '10.044M', '10.005M', '9.994M', '9.983M', '9.942M', '9.876M',
#        '9.864M', '9.827M', '9.803M', '9.747M', '9.6M', '9.598M', '9.563M',
#        '9.555M', '9.513M', '9.433M', '9.418M', '9.39M', '9.377M',
#        '9.326M', '9.308M', '9.253M', '9.213M', '9.165M', '9.077M',
#        '9.053M', '8.998M', '8.923M', '8.91M', '8.841M', '8.812M',
#        '8.755M', '8.724M', '8.722M', '8.669M', '8.635M', '8.582M',
#        '8.554M', '8.496M', '8.395M', '8.351M', '8.329M', '8.279M',
#        '8.238M', '8.108M', '8.099M', '8.09M', '7.966M', '7.937M',
#        '7.905M', '7.807M', '7.8M', '7.742M', '7.738M', '7.685M', '7.67M',
#        '7.658M', '7.644M', '7.629M', '7.549M', '7.536M', '7.469M',
#        '7.443M', '7.438M', '7.412M', '7.401M', '7.361M', '7.348M',
#        '7.34M', '7.337M', '7.223M', '7.204M', '7.138M', '7.122M',
#        '7.019M', '7.007M', '6.998M', '6.972M', '6.953M', '6.947M',
#        '6.918M', '6.903M', '6.853M', '6.848M', '6.824M', '6.821M',
#        '6.768M', '6.748M', '6.734M', '6.698M', '6.697M', '6.624M',
#        '6.534M', '6.53M', '6.526M', '6.508M', '6.502M', '6.495M',
#        '6.406M', '6.339M', '6.334M', '6.317M', '6.297M', '6.202M',
#        '6.175M', '6.122M', '6.12M', '6.117M', '6.048M', '6.043M',
#        '6.028M', '5.97M', '5.969M', '5.961M', '5.895M', '5.874M',
#        '5.865M', '5.85M', '5.828M', '5.818M', '5.809M', '5.769M',
#        '5.751M', '5.736M', '5.73M', '5.715M', '5.707M', '5.69M', '5.68M',
#        '5.675M', '5.65M', '5.637M', '5.585M', '5.572M', '5.54M', '5.539M',
#        '5.53M', '5.489M', '5.415M', '5.414M', '5.413M', '5.401M',
#        '5.383M', '5.38M', '5.351M', '5.303M', '5.301M', '5.278M',
#        '5.277M', '5.276M', '5.272M', '5.265M', '5.255M', '5.254M',
#        '5.205M', '5.185M', '5.184M', '5.152M', '5.148M', '5.13M',
#        '5.117M', '5.111M', '5.105M', '5.093M', '5.071M', '5.059M',
#        '5.058M', '5.046M', '5.036M', '5.001M'], dtype=object)

# %%
stocks_df['volumn'] = stocks_df['volumn'].apply(lambda x : x.replace('M',''))

# %%
stocks_df['volumn']
# Out:
# 0      85.927
# 1       9.079
# 2      58.421
# 3      32.649
# 4       8.033
#         ...
# 310     5.059
# 311     5.058
# 312     5.046
# 313     5.036
# 314     5.001
# Name: volumn, Length: 315, dtype: object

# %%
stocks_df.dtypes
# Out:
# name           object
# symbol         object
# price         float64
# change        float64
# volumn         object
# market_cap     object
# pe_ratio       object
# dtype: object

# %%
stocks_df['volumn'] = stocks_df['volumn'].astype(float)

# %%
stocks_df.dtypes
# Out:
# name           object
# symbol         object
# price         float64
# change        float64
# volumn        float64
# market_cap     object
# pe_ratio       object
# dtype: object

# %%
stocks_df['market_cap']= stocks_df['market_cap'].apply(
    lambda x : float(x.replace('B','')) if 'B' in x else float(x.replace('T',''))*1000 
)

# %%
stocks_df['market_cap'].str.extract(r'([^0-9.])', expand=False).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 stocks_df['market_cap'].str.extract(r'([^0-9.])', expand=False).unique()
#
# File /opt/anaconda3/envs/web_scraping/lib/python3.13/site-packages/pandas/core/generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File /opt/anaconda3/envs/web_scraping/lib/python3.13/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File /opt/anaconda3/envs/web_scraping/lib/python3.13/site-packages/pandas/core/strings/accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File /opt/anaconda3/envs/web_scraping/lib/python3.13/site-packages/pandas/core/strings/accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
stocks_df['market_cap']
# Out:
# 0         1.383
# 1       334.928
# 2        58.703
# 3      3670.000
# 4        68.841
#          ...
# 310      16.785
# 311     119.367
# 312       2.856
# 313      25.499
# 314     137.481
# Name: market_cap, Length: 315, dtype: float64

# %%
stocks_df.dtypes
# Out:
# name           object
# symbol         object
# price         float64
# change        float64
# volumn        float64
# market_cap    float64
# pe_ratio       object
# dtype: object

# %%
stocks_df
# Out:
#                                 name symbol   price  change  volumn  \
# 0        Olema Pharmaceuticals, Inc.   OLMA   20.14   11.62  85.927
# 1               The Home Depot, Inc.     HD  336.48  -21.55   9.079
# 2       Warner Bros. Discovery, Inc.    WBD   23.69    0.95  58.421
# 3              Microsoft Corporation   MSFT  493.79  -13.70  32.649
# 4                   Cloudflare, Inc.    NET  196.53   -5.72   8.033
# ..                               ...    ...     ...     ...     ...
# 310           Southwest Airlines Co.    LUV   31.96    0.11   5.059
# 311  British American Tobacco p.l.c.    BTI   54.86    0.15   5.058
# 312                      Asana, Inc.   ASAN   12.09    0.06   5.046
# 313              General Mills, Inc.    GIS   47.69    0.72   5.036
# 314         Palo Alto Networks, Inc.   PANW  201.00   -1.90   5.001
#
#      market_cap pe_ratio
# 0         1.383       --
# 1       334.928    22.86
# 2        58.703   124.68
# 3      3670.000    35.12
# 4        68.841       --
# ..          ...      ...
# 310      16.785    49.35
# 311     119.367    29.58
# 312       2.856       --
# 313      25.499     9.00
# 314     137.481   128.28
#
# [315 rows x 7 columns]

# %%
stocks_df['pe_ratio'].str.extract(r'([^0-9.])', expand=False).unique()
# Out:
# array([nan], dtype=object)

# %%
stocks_df['pe_ratio'] = stocks_df['pe_ratio'].str.replace(',','')

# %%
stocks_df['pe_ratio'] = stocks_df['pe_ratio'].str.replace('--','')

# %%
stocks_df['pe_ratio'].unique()
# Out:
# array(['--', '22.86', '124.68', '35.12', '279.03', '11.28', '51.32',
#        '14.56', '118.64', '33.16', '788.93', '1612.20', '5.64', '37.02',
#        '15.53', '27.27', '46.48', '129.23', '13.42', '19.16', '26.51',
#        '23.32', '14.37', '8.31', '22.28', '269.29', '32.52', '30.67',
#        '36.52', '36.29', '9.67', '17.82', '26.63', '16.19', '51.24',
#        '9.25', '169.64', '28.97', '68.88', '13.88', '12.30', '11.17',
#        '11.00', '4.57', '28.09', '26.44', '188.56', '26.93', '14.42',
#        '30.12', '8.76', '26.48', '7.31', '51.60', '14.06', '27.96',
#        '24.52', '34.68', '13.82', '22.73', '12.71', '87.97', '219.23',
#        '20.37', '9.93', '13.33', '12.62', '11.75', '21.96', '13.58',
#        '15.70', '38.68', '20.07', '63.78', '74.31', '10.82', '21.51',
#        '5.44', '380.22', '13.09', '22.47', '14.01', '16.17', '1697.31',
#        '15.39', '22.67', '17.32', '17.68', '107.75', '23.59', '47.16',
#        '9.78', '26.27', '12.60', '49.96', '9.24', '18.93', '24.73',
#        '23.57', '76.10', '32.72', '16.33', '23.43', '32.94', '8.56',
#        '13.74', '15.45', '8.89', '12.15', '19.47', '9.86', '22.10',
#        '11.54', '26.10', '21.03', '84.24', '24.63', '14.11', '10.48',
#        '34.73', '22.06', '14.81', '47.62', '26.62', '21.55', '16.75',
#        '135.80', '129.61', '8.44', '64.15', '14.64', '111.78', '10.14',
#        '54.92', '87.18', '29.02', '28.63', '21.12', '32.35', '10.15',
#        '6.50', '19.74', '30.75', '11.10', '10.27', '17.01', '64.46',
#        '19.72', '9.12', '22.11', '18.01', '16.78', '19.37', '33.26',
#        '14.87', '12.09', '10.57', '12.29', '7.67', '8.50', '10.78',
#        '35.41', '16.46', '12.93', '7.61', '23.36', '209.87', '26.79',
#        '27.74', '17.58', '9.98', '15.04', '19.03', '49.95', '16.35',
#        '108.38', '13.87', '19.90', '22.22', '19.46', '8.98', '8.72',
#        '3.81', '26.32', '44.58', '29.59', '13.66', '38.18', '29.88',
#        '23.23', '19.91', '20.35', '25.84', '340.44', '62.15', '149.03',
#        '32.31', '20.61', '11.98', '34.29', '9.49', '18.72', '21.01',
#        '25.00', '10.41', '14.83', '21.83', '16.40', '13.59', '37.83',
#        '15.55', '40.70', '12.70', '52.64', '49.35', '29.58', '9.00',
#        '128.28'], dtype=object)

# %%
stocks_df['pe_ratio'] = stocks_df['pe_ratio'].replace(',','')

# %%
stocks_df['pe_ratio'] = pd.to_numeric(stocks_df['pe_ratio'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "--"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 stocks_df['pe_ratio'] = pd.to_numeric(stocks_df['pe_ratio'])
#
# File /opt/anaconda3/envs/web_scraping/lib/python3.13/site-packages/pandas/core/tools/numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
#     237         set(),
#     238         coerce_numeric=coerce_numeric,
#     239         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     240         or isinstance(values_dtype, StringDtype)
#     241         and values_dtype.na_value is libmissing.NA,
#     242     )
#     243 except (ValueError, TypeError):
#     244     if errors == "raise":
#
# File pandas/_libs/lib.pyx:2449, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "--" at position 0

# %%
stocks_df.dtypes
# Out:
# name             object
# symbol           object
# price_usd       float64
# change          float64
# volumn          float64
# market_cap_B    float64
# pe_ratio        float64
# dtype: object

# %%
stocks_df.rename(
   columns =  {
       "price": "price_usd",
		"volume": "volume_M",
		"market_cap": "market_cap_B"
       }, inplace=True
)

# %%
stocks_df
# Out:
#                                       name symbol  price_usd  change   volumn  \
# 0                              Tesla, Inc.   TSLA     445.91  -16.35  104.867
# 1                                Snap Inc.   SNAP       8.01    0.71  155.951
# 2                              Pfizer Inc.    PFE      24.85    0.24  111.564
# 3                              Tesla, Inc.   TSLA     445.88  -16.38   96.048
# 4               Opendoor Technologies Inc.   OPEN       6.56   -0.67   89.793
# ..                                     ...    ...        ...     ...      ...
# 352  Vodafone Group Public Limited Company    VOD      11.34    0.07    5.046
# 353                       Fastenal Company   FAST      40.77   -0.91    5.043
# 354            DigitalOcean Holdings, Inc.   DOCN      47.08    1.27    5.043
# 355                   Fluence Energy, Inc.   FLNC      19.82   -0.90    5.019
# 356            International Paper Company     IP      36.54    0.22    5.010
#
#      market_cap_B  pe_ratio
# 0        1483.000    303.34
# 1          13.536       NaN
# 2         195.108     14.12
# 3        1483.000    306.57
# 4           4.868       NaN
# ..            ...       ...
# 352        27.731       NaN
# 353        46.805     38.63
# 354         4.306     14.70
# 355         3.617       NaN
# 356        19.292       NaN
#
# [357 rows x 7 columns]

# %%
stocks_df.isnull().sum()
# Out:
# name              0
# symbol            0
# price_usd         0
# change            0
# volumn            0
# market_cap_B      0
# pe_ratio        155
# dtype: int64

# %%
stocks_df.to_excel("yahoo-stocks-data.xlsx", index=False)
